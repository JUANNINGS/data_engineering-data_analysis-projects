# %% [markdown]
# # Instacart Market Basket Analysis
#
# ## Using XGBoost in SageMaker

# %% [markdown]
# ## Step 1: Preprocess the data

# %%
# read the data into dataframe
import pandas as pd

bucket='my_bucket_name'

data_key = 'output_small/data_small.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

data = pd.read_csv(data_location)

# %%
# load order product train dataframe
order_product_train_key = 'data/order_products/order_products__train.csv.gz'
order_product_train_location = 's3://{}/{}'.format(bucket, order_product_train_key)

order_product_train = pd.read_csv(order_product_train_location)

# %%
# have a look at the data
order_product_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
# load orders dataframe
orders_key = 'data/orders/orders.csv'
orders_location = 's3://{}/{}'.format(bucket, orders_key)

orders = pd.read_csv(orders_location)
orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0
#
# [3421083 rows x 7 columns]

# %%
# attach user_id to order_product_train
order_product_train = order_product_train.merge(orders[['user_id', 'order_id']])
order_product_train
# Out:
#          order_id  product_id  add_to_cart_order  reordered  user_id
# 0               1       49302                  1          1   112108
# 1               1       11109                  2          1   112108
# 2               1       10246                  3          0   112108
# 3               1       49683                  4          0   112108
# 4               1       43633                  5          1   112108
# ...           ...         ...                ...        ...      ...
# 1384612   3421063       14233                  3          1   169679
# 1384613   3421063       35548                  4          1   169679
# 1384614   3421070       35951                  1          1   139822
# 1384615   3421070       16953                  2          1   139822
# 1384616   3421070        4724                  3          1   139822
#
# [1384617 rows x 5 columns]

# %%
# attach eval_set to data
data = data.merge(orders[orders.eval_set != 'prior'][['user_id','eval_set']])
data
# Out:
#          product_id  up_orders  user_mean_days_since_prior  user_period  \
# 0             19508          6                    5.969574         2943
# 1             42307          1                    5.969574         2943
# 2             35883          1                    5.969574         2943
# 3             13539          1                    5.969574         2943
# 4             27966          3                    5.969574         2943
# ...             ...        ...                         ...          ...
# 1330790       16741          1                    5.381579          409
# 1330791       24852          1                   12.000000          132
# 1330792       34969          1                   21.818182          240
# 1330793         778          1                   13.210526          251
# 1330794       23405          2                    7.000000           56
#
#          user_distinct_products  prod_second_orders  prod_reorders  \
# 0                           200                2869           6681
# 1                           200                 349           1549
# 2                           200                 245            692
# 3                           200                  15             23
# 4                           200               19341         105409
# ...                         ...                 ...            ...
# 1330790                      27                  18             57
# 1330791                       9               55166         398609
# 1330792                      13                9548          34812
# 1330793                      18                 107            385
# 1330794                      10                1065           1805
#
#          user_reorder_ratio  user_total_products  up_average_cart_position  \
# 0                  0.602434                  497                  7.833333
# 1                  0.602434                  497                  3.000000
# 2                  0.602434                  497                  8.000000
# 3                  0.602434                  497                 12.000000
# 4                  0.602434                  497                  7.000000
# ...                     ...                  ...                       ...
# 1330790            0.684211                   79                  5.000000
# 1330791            0.272727                   12                  2.000000
# 1330792            0.454545                   18                  5.000000
# 1330793            0.421053                   26                  3.000000
# 1330794            0.375000                   13                  1.500000
#
#          up_first_order  user_orders  up_last_order  prod_orders  \
# 0                    11           61             29        14905
# 1                    55           61             55         2188
# 2                    52           61             52         1377
# 3                    50           61             50          108
# 4                    53           61             61       137057
# ...                 ...          ...            ...          ...
# 1330790              13           14             13          116
# 1330791               4            5              4       472565
# 1330792               1            3              1        54409
# 1330793               3            4              3          707
# 1330794               2            3              3         7952
#
#          prod_first_orders  user_id eval_set
# 0                     8224   144185     test
# 1                      639   144185     test
# 2                      685   144185     test
# 3                       85   144185     test
# 4                    31648   144185     test
# ...                    ...      ...      ...
# 1330790                 59    63137    train
# 1330791              73956    15227    train
# 1330792              19597    34223     test
# 1330793                322   144251    train
# 1330794               6147    74381    train
#
# [1330795 rows x 17 columns]

# %%
# attach target variable: reordered
data = data.merge(order_product_train[['user_id', 'product_id', 'reordered']], how = 'left')
data
# Out:
#          product_id  up_orders  user_mean_days_since_prior  user_period  \
# 0             19508          6                    5.969574         2943
# 1             21681          1                    6.675781         3418
# 2             31487          1                   10.865079         1369
# 3             32610          1                    8.377778          754
# 4             18171          2                   12.500000         2400
# ...             ...        ...                         ...          ...
# 1330790         778          1                   13.210526          251
# 1330791        8571          2                    9.216387         4387
# 1330792       23405          2                    7.000000           56
# 1330793       21137         38                    4.477180         9908
# 1330794       16797          1                   13.116959         4486
#
#          user_distinct_products  prod_second_orders  prod_reorders  \
# 0                           200                2869           6681
# 1                           209                 186            358
# 2                            67                 545           1702
# 3                            76                  31             78
# 4                            70                 561           1650
# ...                         ...                 ...            ...
# 1330790                      18                 107            385
# 1330791                      75                2014          11282
# 1330792                      10                1065           1805
# 1330793                     265               38131         205845
# 1330794                     188               24449          99802
#
#          user_reorder_ratio  user_total_products  up_average_cart_position  \
# 0                  0.602434                  497                  7.833333
# 1                  0.595703                  514                 10.000000
# 2                  0.515873                  132                  8.000000
# 3                  0.344444                  107                  8.000000
# 4                  0.687500                  202                  7.500000
# ...                     ...                  ...                       ...
# 1330790            0.421053                   26                  3.000000
# 1330791            0.886555                  497                 18.500000
# 1330792            0.375000                   13                  1.500000
# 1330793            0.894261                 2244                  9.105263
# 1330794            0.485380                  354                  3.000000
#
#          up_first_order  user_orders  up_last_order  prod_orders  \
# 0                    11           61             29        14905
# 1                    11           57             11         1599
# 2                     5           27              5         3049
# 3                     9            9              9          198
# 4                     3           24             19         3128
# ...                 ...          ...            ...          ...
# 1330790               3            4              3          707
# 1330791               2           20             12        14399
# 1330792               2            3              3         7952
# 1330793               1           80             58       264683
# 1330794               7           20              7       142951
#
#          prod_first_orders  user_id  reordered
# 0                     8224   144185        NaN
# 1                     1241    83415        NaN
# 2                     1347    39777        NaN
# 3                      120   184494        NaN
# 4                     1478   132468        NaN
# ...                    ...      ...        ...
# 1330790                322   144251        NaN
# 1330791               3117   144159        NaN
# 1330792               6147    74381        NaN
# 1330793              58838   145686        NaN
# 1330794              43149    17544        NaN
#
# [1330795 rows x 17 columns]

# %%
# a few more feature engineering, refer to the R code
data['prod_reorder_probability'] = data.prod_second_orders / data.prod_first_orders
data['prod_reorder_times'] = 1 + data.prod_reorders / data.prod_first_orders
data['prod_reorder_ratio'] = data.prod_reorders / data.prod_orders
data.drop(['prod_reorders', 'prod_first_orders', 'prod_second_orders'], axis=1, inplace=True)
data['user_average_basket'] = data.user_total_products / data.user_orders
data['up_order_rate'] = data.up_orders / data.user_orders
data['up_orders_since_last_order'] = data.user_orders - data.up_last_order
data['up_order_rate_since_first_order'] = data.up_orders / (data.user_orders - data.up_first_order + 1)

# %%
data
# Out:
#          product_id  up_orders  user_mean_days_since_prior  user_period  \
# 0             19508          6                    5.969574         2943
# 1             21681          1                    6.675781         3418
# 2             31487          1                   10.865079         1369
# 3             32610          1                    8.377778          754
# 4             18171          2                   12.500000         2400
# ...             ...        ...                         ...          ...
# 1330790         778          1                   13.210526          251
# 1330791        8571          2                    9.216387         4387
# 1330792       23405          2                    7.000000           56
# 1330793       21137         38                    4.477180         9908
# 1330794       16797          1                   13.116959         4486
#
#          user_distinct_products  user_reorder_ratio  user_total_products  \
# 0                           200            0.602434                  497
# 1                           209            0.595703                  514
# 2                            67            0.515873                  132
# 3                            76            0.344444                  107
# 4                            70            0.687500                  202
# ...                         ...                 ...                  ...
# 1330790                      18            0.421053                   26
# 1330791                      75            0.886555                  497
# 1330792                      10            0.375000                   13
# 1330793                     265            0.894261                 2244
# 1330794                     188            0.485380                  354
#
#          up_average_cart_position  up_first_order  user_orders  ...  \
# 0                        7.833333              11           61  ...
# 1                       10.000000              11           57  ...
# 2                        8.000000               5           27  ...
# 3                        8.000000               9            9  ...
# 4                        7.500000               3           24  ...
# ...                           ...             ...          ...  ...
# 1330790                  3.000000               3            4  ...
# 1330791                 18.500000               2           20  ...
# 1330792                  1.500000               2            3  ...
# 1330793                  9.105263               1           80  ...
# 1330794                  3.000000               7           20  ...
#
#          prod_orders  user_id  reordered  prod_reorder_probability  \
# 0              14905   144185        NaN                  0.348857
# 1               1599    83415        NaN                  0.149879
# 2               3049    39777        NaN                  0.404603
# 3                198   184494        NaN                  0.258333
# 4               3128   132468        NaN                  0.379567
# ...              ...      ...        ...                       ...
# 1330790          707   144251        NaN                  0.332298
# 1330791        14399   144159        NaN                  0.646134
# 1330792         7952    74381        NaN                  0.173255
# 1330793       264683   145686        NaN                  0.648068
# 1330794       142951    17544        NaN                  0.566618
#
#          prod_reorder_times  prod_reorder_ratio  user_average_basket  \
# 0                  1.812378            0.448239             8.147541
# 1                  1.288477            0.223890             9.017544
# 2                  2.263549            0.558216             4.888889
# 3                  1.650000            0.393939            11.888889
# 4                  2.116373            0.527494             8.416667
# ...                     ...                 ...                  ...
# 1330790            2.195652            0.544554             6.500000
# 1330791            4.619506            0.783527            24.850000
# 1330792            1.293639            0.226987             4.333333
# 1330793            4.498504            0.777704            28.050000
# 1330794            3.312962            0.698155            17.700000
#
#          up_order_rate  up_orders_since_last_order  \
# 0             0.098361                          32
# 1             0.017544                          46
# 2             0.037037                          22
# 3             0.111111                           0
# 4             0.083333                           5
# ...                ...                         ...
# 1330790       0.250000                           1
# 1330791       0.100000                           8
# 1330792       0.666667                           0
# 1330793       0.475000                          22
# 1330794       0.050000                          13
#
#          up_order_rate_since_first_order
# 0                               0.117647
# 1                               0.021277
# 2                               0.043478
# 3                               1.000000
# 4                               0.090909
# ...                                  ...
# 1330790                         0.500000
# 1330791                         0.105263
# 1330792                         1.000000
# 1330793                         0.475000
# 1330794                         0.071429
#
# [1330795 rows x 21 columns]

# %%
# split into training and test set, test set does not have target variable
train = data[data.eval_set == 'train'].copy()
test = data[data.eval_set == 'test'].copy()
train
# Out:
#          product_id  up_orders  user_mean_days_since_prior  user_period  \
# 14            21681          1                    6.675781         3418
# 15            13984          3                    6.675781         3418
# 16            22395          1                    6.675781         3418
# 17             3252          1                    6.675781         3418
# 18            31506          4                    6.675781         3418
# ...             ...        ...                         ...          ...
# 1330789        9434          1                   21.027027          778
# 1330790       16741          1                    5.381579          409
# 1330791       24852          1                   12.000000          132
# 1330793         778          1                   13.210526          251
# 1330794       23405          2                    7.000000           56
#
#          user_distinct_products  user_reorder_ratio  user_total_products  \
# 14                          209            0.595703                  514
# 15                          209            0.595703                  514
# 16                          209            0.595703                  514
# 17                          209            0.595703                  514
# 18                          209            0.595703                  514
# ...                         ...                 ...                  ...
# 1330789                      25            0.432432                   41
# 1330790                      27            0.684211                   79
# 1330791                       9            0.272727                   12
# 1330793                      18            0.421053                   26
# 1330794                      10            0.375000                   13
#
#          up_average_cart_position  up_first_order  user_orders  ...  user_id  \
# 14                          10.00              11           57  ...    83415
# 15                           5.00              10           57  ...    83415
# 16                           5.00              15           57  ...    83415
# 17                           4.00              48           57  ...    83415
# 18                           3.25              16           57  ...    83415
# ...                           ...             ...          ...  ...      ...
# 1330789                      4.00               4           10  ...   144232
# 1330790                      5.00              13           14  ...    63137
# 1330791                      2.00               4            5  ...    15227
# 1330793                      3.00               3            4  ...   144251
# 1330794                      1.50               2            3  ...    74381
#
#          eval_set  reordered prod_reorder_probability  prod_reorder_times  \
# 14          train        NaN                 0.149879            1.288477
# 15          train        NaN                 0.400536            2.206638
# 16          train        NaN                 0.340970            1.825202
# 17          train        NaN                 0.233766            1.448052
# 18          train        NaN                 0.377514            1.910764
# ...           ...        ...                      ...                 ...
# 1330789     train        NaN                 0.413609            2.047401
# 1330790     train        NaN                 0.305085            1.966102
# 1330791     train        1.0                 0.745930            6.389813
# 1330793     train        NaN                 0.332298            2.195652
# 1330794     train        NaN                 0.173255            1.293639
#
#          prod_reorder_ratio  user_average_basket  up_order_rate  \
# 14                 0.223890             9.017544       0.017544
# 15                 0.546822             9.017544       0.052632
# 16                 0.452115             9.017544       0.017544
# 17                 0.309417             9.017544       0.017544
# 18                 0.476649             9.017544       0.070175
# ...                     ...                  ...            ...
# 1330789            0.511576             4.100000       0.100000
# 1330790            0.491379             5.642857       0.071429
# 1330791            0.843501             2.400000       0.200000
# 1330793            0.544554             6.500000       0.250000
# 1330794            0.226987             4.333333       0.666667
#
#          up_orders_since_last_order  up_order_rate_since_first_order
# 14                               46                         0.021277
# 15                               17                         0.062500
# 16                               42                         0.023256
# 17                                9                         0.100000
# 18                               25                         0.095238
# ...                             ...                              ...
# 1330789                           6                         0.142857
# 1330790                           1                         0.500000
# 1330791                           1                         0.500000
# 1330793                           1                         0.500000
# 1330794                           0                         1.000000
#
# [846992 rows x 22 columns]

# %%
# id field won't be used in model, thus make a backup of them and remove from dataframe
test_id = test[['product_id','user_id', 'eval_set']]
test.drop(['product_id','user_id', 'eval_set', 'reordered'], axis=1, inplace=True)
test
# Out:
#          up_orders  user_mean_days_since_prior  user_period  \
# 0                6                    5.969574         2943
# 1                1                    5.969574         2943
# 2                1                    5.969574         2943
# 3                1                    5.969574         2943
# 4                3                    5.969574         2943
# ...            ...                         ...          ...
# 1330780          9                   26.212121         1730
# 1330783          1                   26.760000          669
# 1330784          1                   10.250000           82
# 1330786          2                    8.578947          489
# 1330792          1                   21.818182          240
#
#          user_distinct_products  user_reorder_ratio  user_total_products  \
# 0                           200            0.602434                  497
# 1                           200            0.602434                  497
# 2                           200            0.602434                  497
# 3                           200            0.602434                  497
# 4                           200            0.602434                  497
# ...                         ...                 ...                  ...
# 1330780                      30            0.681818                   75
# 1330783                      22            0.160000                   26
# 1330784                      11            0.000000                   11
# 1330786                      49            0.245614                   63
# 1330792                      13            0.454545                   18
#
#          up_average_cart_position  up_first_order  user_orders  up_last_order  \
# 0                        7.833333              11           61             29
# 1                        3.000000              55           61             55
# 2                        8.000000              52           61             52
# 3                       12.000000              50           61             50
# 4                        7.000000              53           61             61
# ...                           ...             ...          ...            ...
# 1330780                  3.444444               1            9              9
# 1330783                  2.000000               4            8              4
# 1330784                  5.000000               2            3              2
# 1330786                  4.500000               1            7              4
# 1330792                  5.000000               1            3              1
#
#          prod_orders  prod_reorder_probability  prod_reorder_times  \
# 0              14905                  0.348857            1.812378
# 1               2188                  0.546166            3.424100
# 2               1377                  0.357664            2.010219
# 3                108                  0.176471            1.270588
# 4             137057                  0.611129            4.330669
# ...              ...                       ...                 ...
# 1330780        56087                  0.623136            5.326907
# 1330783         5874                  0.407210            2.406391
# 1330784        17716                  0.381535            1.917524
# 1330786         4774                  0.556540            3.252044
# 1330792        54409                  0.487217            2.776394
#
#          prod_reorder_ratio  user_average_basket  up_order_rate  \
# 0                  0.448239             8.147541       0.098361
# 1                  0.707952             8.147541       0.016393
# 2                  0.502542             8.147541       0.016393
# 3                  0.212963             8.147541       0.016393
# 4                  0.769089             8.147541       0.049180
# ...                     ...                  ...            ...
# 1330780            0.812274             8.333333       1.000000
# 1330783            0.584440             3.250000       0.125000
# 1330784            0.478494             3.666667       0.333333
# 1330786            0.692501             9.000000       0.285714
# 1330792            0.639821             6.000000       0.333333
#
#          up_orders_since_last_order  up_order_rate_since_first_order
# 0                                32                         0.117647
# 1                                 6                         0.142857
# 2                                 9                         0.100000
# 3                                11                         0.083333
# 4                                 0                         0.333333
# ...                             ...                              ...
# 1330780                           0                         1.000000
# 1330783                           4                         0.200000
# 1330784                           1                         0.500000
# 1330786                           3                         0.285714
# 1330792                           2                         0.333333
#
# [483803 rows x 18 columns]

# %%
# convert target variable to 1/0 for training dataframe
train['reordered'] = train['reordered'].fillna(0)
train['reordered'] = train.reordered.astype(int)

# %%
# drop id columns as they won't be used in model
train.drop(['eval_set', 'user_id', 'product_id'], axis=1, inplace=True)

# %%
# this is the target variable dataframe
train_y = train[['reordered']]
# this is the dataframe without target variable
train_X = train.drop(['reordered'], axis = 1)

# %% [markdown]
# ## Step 2: Classification

# %%
import pandas as pd

val_X = train_X[:20000]
train_X = train_X[20000:]

val_y = train_y[:20000]
train_y = train_y[20000:]

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
import os
data_dir = 'data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory without label.
pd.DataFrame(test).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# Then we save the training and validation set into local disk as csv files
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'imba-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### Creating a tuned XGBoost model

# %%
from sagemaker import get_execution_role

role = get_execution_role()

# %%
import sagemaker
container = sagemaker.image_uris.retrieve('xgboost', session.boto_region_name, 'latest')

# %%
xgb = sagemaker.estimator.Estimator(container, 
                                    role,                                    
                                    train_instance_count=1,                  
                                    train_instance_type='ml.m4.xlarge',      
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

xgb.set_hyperparameters(max_depth=5,
                        eta=0.1,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Create the hyperparameter tuner

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner


# create the tuner object:

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, 
                                               objective_metric_name = 'validation:rmse', 
                                               objective_type = 'Minimize', 
                                               max_jobs = 4, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner

# %%
s3_input_train = sagemaker.TrainingInput(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.TrainingInput(s3_data=val_location, content_type='csv')
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# ...................................................................................................!

# %% [markdown]
# ### Testing the model

# %%
# attach the model:

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2021-12-29 11:33:39 Starting - Preparing the instances for training
# 2021-12-29 11:33:39 Downloading - Downloading input data
# 2021-12-29 11:33:39 Training - Training image download completed. Training in progress.
# 2021-12-29 11:33:39 Uploading - Uploading generated training model
# 2021-12-29 11:33:39 Completed - Training job completed

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %%
# Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
# Out:
# ...................................Arguments: serve
# [2021-12-29 11:40:08 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2021-12-29 11:40:08 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-12-29 11:40:08 +0000] [1] [INFO] Using worker: gevent
# [2021-12-29 11:40:08 +0000] [21] [INFO] Booting worker with pid: 21
# [2021-12-29 11:40:08 +0000] [22] [INFO] Booting worker with pid: 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-29:11:40:08:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-29:11:40:08:INFO] Model loaded successfully for worker : 22
# [2021-12-29 11:40:08 +0000] [23] [INFO] Booting worker with pid: 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-29:11:40:08:INFO] Model loaded successfully for worker : 23
# [2021-12-29 11:40:08 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-29:11:40:08:INFO] Model loaded successfully for worker : 24
# 2021-12-29T11:40:12.309:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2021-12-29:11:40:13:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:13:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:14:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:14:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:13:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:13:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:14:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:14:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:14:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:14:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:14:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:14:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:15:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:15:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:16:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:16:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:16:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:17:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:17:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:16:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:17:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:17:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:17:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:17:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:17:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:17:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','
# [2021-12-29:11:40:18:INFO] Sniff delimiter as ','
# [2021-12-29:11:40:18:INFO] Determined delimiter of CSV input is ','

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-ap-southeast-2-111611805220/xgboost-2021-12-29-11-34-24-859/test.csv.out to data/xgboost/test.csv.out

# %%
prediction=pd.read_csv('data/xgboost/test.csv.out', header=None, names=["prob"])
test_id = test_id.reset_index().drop(['index','eval_set'],axis = 1)
test = test.reset_index().drop(['index'],axis = 1)
pd.concat([test_id,test],axis=1).to_csv('data/xgboost/test_final.csv', index = False)
# !aws s3 cp 'data/xgboost/test_final.csv' 's3://{bucket}/model_output/test_final.csv'
# Out:
# upload: data/xgboost/test_final.csv to s3://imba-johnny/model_output/test_final.csv

# %% [markdown]
# ## Step 3: Putting our model to work

# %%
import boto3

runtime = boto3.Session().client('sagemaker-runtime')

# %%
# now we deploy the model as an endpoint
xgb_predictor = xgb_attached.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# -----!

# %%
# make a note of the model endpoint been created
xgb_predictor.endpoint
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 'xgboost-2021-12-29-11-41-22-248'

# %%
# let's invoke the endpoint and see if it works
response = runtime.invoke_endpoint(EndpointName = xgb_predictor.endpoint, 
                                       ContentType = 'text/csv',                     
                                       Body = '1,6.67578125,3418,209,0.595703125,514,10.0,11,57,11,1599,0.1498791297340854,1.2884770346494763,0.22388993120700437,9.017543859649123,0.017543859649122806,46,0.02127659574468085')
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# here is the response: the probablility of a user buy the product
response['Body'].read().decode('utf-8')
# Out:
# '0.008685070089995861'

# %% [markdown]
# ### Delete the endpoint

# %%
xgb_predictor.delete_endpoint()
